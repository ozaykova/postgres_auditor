# %%
default = [
    {'conn':  1, 'latency':  0.259 , 'tps':  3861.003861, 'init_conn_time':  1.946 },
    {'conn':  10, 'latency':  1.277 , 'tps':  7829.014327, 'init_conn_time':  6.384 },
    {'conn':  20, 'latency':  1.704 , 'tps':  11736.400446, 'init_conn_time':  12.681 },
    {'conn':  30, 'latency':  3.014 , 'tps':  9952.889656, 'init_conn_time':  14.397 },
    {'conn':  40, 'latency':  4.081 , 'tps':  9802.239812, 'init_conn_time':  17.786 },
    {'conn':  50, 'latency':  4.336 , 'tps':  11530.567535, 'init_conn_time':  23.467 },
    {'conn':  60, 'latency':  4.650 , 'tps':  12903.225806, 'init_conn_time':  27.623 },
    {'conn':  70, 'latency':  5.444 , 'tps':  12857.720143, 'init_conn_time':  41.424 },
    {'conn':  80, 'latency':  6.164 , 'tps':  12979.427607, 'init_conn_time':  42.039 },
    {'conn':  90, 'latency':  8.020 , 'tps':  11221.525379, 'init_conn_time':  48.861 },
    {'conn':  100, 'latency':  8.529 , 'tps':  11724.291560, 'init_conn_time':  63.808 },
    {'conn':  110, 'latency':  9.918 , 'tps':  11490.722107, 'init_conn_time':  77.344 },
    {'conn':  120, 'latency':  8.657 , 'tps':  13861.134534, 'init_conn_time':  66.611 },
    {'conn':  150, 'latency':  11.309 , 'tps':  13264.358668, 'init_conn_time':  98.787 },
    {'conn':  200, 'latency':  16.100 , 'tps':  12822.205935, 'init_conn_time':  108.625 },
    {'conn':  300, 'latency':  22.776 , 'tps':  13171.817579, 'init_conn_time':  159.251 },
    {'conn':  400, 'latency':  28.874 , 'tps':  13753.437557, 'init_conn_time':  199.821 },
    {'conn':  500, 'latency':  37.824 , 'tps':  13219.015289, 'init_conn_time':  275.302 },
    {'conn':  600, 'latency':  45.583 , 'tps':  13162.715293, 'init_conn_time':  304.335 },
    {'conn':  700, 'latency':  53.283 , 'tps':  13237.521700, 'init_conn_time':  341.640 },
    {'conn':  800, 'latency':  59.163 , 'tps':  12721.850465, 'init_conn_time':  387.782 },
    {'conn':  900, 'latency':  75.533 , 'tps':  12943.531686, 'init_conn_time':  442.923 },
    {'conn':  1000, 'latency':  82.669 , 'tps':  12429.176584, 'init_conn_time':  462.667 },
]

configured = [
    {'conn':  1, 'latency':  0.282 , 'tps':  3542.330854, 'init_conn_time':  2.552 },
    {'conn':  10, 'latency':  0.682 , 'tps':  14669.209330, 'init_conn_time':  6.273 },
    {'conn':  20, 'latency':  1.582 , 'tps':  12639.828098, 'init_conn_time':  11.184 },
    {'conn':  30, 'latency':  3.540 , 'tps':  10175.055088, 'init_conn_time':  14.191 },
    {'conn':  40, 'latency':  3.280 , 'tps':  12196.237461, 'init_conn_time':  19.181 },
    {'conn':  50, 'latency':  3.929 , 'tps':  12727.180166, 'init_conn_time':  21.910 },
    {'conn':  60, 'latency':  4.486 , 'tps':  13374.348001, 'init_conn_time':  27.284 },
    {'conn':  70, 'latency':  4.987 , 'tps':  14037.339323, 'init_conn_time':  34.726 },
    {'conn':  80, 'latency':  5.650 , 'tps':  14158.289679, 'init_conn_time':  44.788 },
    {'conn':  90, 'latency':  6.295 , 'tps':  14297.742545, 'init_conn_time':  50.409 },
    {'conn':  100, 'latency':  6.911 , 'tps':  14469.476639, 'init_conn_time':  54.448 },
    {'conn':  110, 'latency':  9.533 , 'tps':  11539.228131, 'init_conn_time':  66.335 },
    {'conn':  120, 'latency':  9.966 , 'tps':  12041.180838, 'init_conn_time':  84.650 },
    {'conn':  150, 'latency':  10.693 , 'tps':  14027.606329, 'init_conn_time':  94.062 },
    {'conn':  200, 'latency':  14.537 , 'tps':  13758.186121, 'init_conn_time':  109.772 },
    {'conn':  300, 'latency':  22.559 , 'tps':  13298.284965, 'init_conn_time':  155.525 },
    {'conn':  400, 'latency':  28.816 , 'tps':  13881.177124, 'init_conn_time':  208.203 },
    {'conn':  500, 'latency':  37.445 , 'tps':  13352.988933, 'init_conn_time':  237.512 },
    {'conn':  600, 'latency':  42.878 , 'tps':  13993.255251, 'init_conn_time':  292.778 },
    {'conn':  700, 'latency':  51.813 , 'tps':  13091.015252, 'init_conn_time':  345.695 },
    {'conn':  800, 'latency':  56.445 , 'tps':  13688.129654, 'init_conn_time':  413.310 },
    {'conn':  900, 'latency':  65.936 , 'tps':  13649.496106, 'init_conn_time':  425.695 },
    {'conn':  1000, 'latency':  71.508 , 'tps':  13584.488405, 'init_conn_time':  475.883 },
]

import matplotlib.pyplot as plt

x = [x['conn'] for x in default]
y = [x['latency'] for x in default]

q = [x['conn'] for x in configured]
w = [x['latency'] for x in configured]

fig, ax = plt.subplots()

default_f, = ax.plot(x, y, label='default')
configured_f, = ax.plot(q, w, label='configured')
ax.legend(handles=[default_f, configured_f])
plt.title('Зависимость latency от числа подключений')
plt.ylabel('latency, ms')
plt.xlabel('connections count')
plt.show()

# %%
x = [x['conn'] for x in default[18:]]
y = [x['latency'] for x in default[18:]]

q = [x['conn'] for x in configured[18:]]
w = [x['latency'] for x in configured[18:]]

fig, ax = plt.subplots()

default_f, = ax.plot(x, y, label='default')
configured_f, = ax.plot(q, w, label='configured')
ax.legend(handles=[default_f, configured_f])
plt.title('Зависимость latency от числа подключений, 600-1000 connctions')
plt.ylabel('latency, ms')
plt.xlabel('connections count')
plt.show()

# %%
x = [x['conn'] for x in default[11:]]
y = [x['tps'] for x in default[11:]]

q = [x['conn'] for x in configured[11:]]
w = [x['tps'] for x in configured[11:]]

fig, ax = plt.subplots()

default_f, = ax.plot(x, y, label='default')
configured_f, = ax.plot(q, w, label='configured')
ax.legend(handles=[default_f, configured_f])
plt.title('Зависимость пропускной способности от числа подключений')
plt.ylabel('tps')
plt.xlabel('connections count')
plt.show()
