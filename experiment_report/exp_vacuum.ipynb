# %%
default = [
    {'conn':  1, 'latency':  0.910 , 'tps':  1099.263493, 'init_conn_time':  1.793 },
    {'conn':  10, 'latency':  4.752 , 'tps':  2104.199983, 'init_conn_time':  7.186 },
    {'conn':  20, 'latency':  10.058 , 'tps':  1988.427353, 'init_conn_time':  11.148 },
    {'conn':  30, 'latency':  15.608 , 'tps':  1922.103550, 'init_conn_time':  15.536 },
    {'conn':  40, 'latency':  22.784 , 'tps':  1755.587156, 'init_conn_time':  17.842 },
    {'conn':  50, 'latency':  29.461 , 'tps':  1697.158956, 'init_conn_time':  25.819 },
    {'conn':  60, 'latency':  35.895 , 'tps':  1671.546654, 'init_conn_time':  32.220 },
    {'conn':  70, 'latency':  39.561 , 'tps':  1769.414905, 'init_conn_time':  34.899 },
    {'conn':  80, 'latency':  46.992 , 'tps':  1702.413810, 'init_conn_time':  38.547 },
    {'conn':  90, 'latency':  57.564 , 'tps':  1563.469025, 'init_conn_time':  57.154 },
    {'conn':  100, 'latency':  59.521 , 'tps':  1680.082122, 'init_conn_time':  52.955 },
    {'conn':  110, 'latency':  61.903 , 'tps':  1776.962170, 'init_conn_time':  54.446 },
    {'conn':  120, 'latency':  73.396 , 'tps':  1634.959800, 'init_conn_time':  74.445 },
    {'conn':  150, 'latency':  89.820 , 'tps':  1670.002961, 'init_conn_time':  79.167 },
    {'conn':  200, 'latency':  130.622 , 'tps':  1531.132127, 'init_conn_time':  108.734 },
    {'conn':  300, 'latency':  240.293 , 'tps':  1248.475300, 'init_conn_time':  171.055 },
    {'conn':  400, 'latency':  425.211 , 'tps':  940.708772, 'init_conn_time':  212.285 },
    {'conn':  500, 'latency':  773.419 , 'tps':  646.480444, 'init_conn_time':  375.771 },
    {'conn':  600, 'latency':  970.572 , 'tps':  618.192095, 'init_conn_time':  406.209 },
    {'conn':  700, 'latency':  1279.771 , 'tps':  546.973028, 'init_conn_time':  476.911 },
    {'conn':  800, 'latency':  1514.306 , 'tps':  528.294810, 'init_conn_time':  586.976 },
    {'conn':  900, 'latency':  2051.439 , 'tps':  438.716540, 'init_conn_time':  555.996 },
    {'conn':  1000, 'latency':  2734.128 , 'tps':  365.747338, 'init_conn_time':  704.242 },

]

configured = [
    {'conn':  1, 'latency':  1.030 , 'tps':  970.873786, 'init_conn_time':  2.533 },
{'conn':  10, 'latency':  5.143 , 'tps':  1944.466050, 'init_conn_time':  9.748 },
{'conn':  20, 'latency':  10.787 , 'tps':  1853.997683, 'init_conn_time':  16.752 },
{'conn':  30, 'latency':  15.546 , 'tps':  1929.794091, 'init_conn_time':  20.295 },
{'conn':  40, 'latency':  19.930 , 'tps':  2006.984305, 'init_conn_time':  19.977 },
{'conn':  50, 'latency':  25.637 , 'tps':  1950.298591, 'init_conn_time':  25.385 },
{'conn':  60, 'latency':  31.988 , 'tps':  1875.715116, 'init_conn_time':  28.049 },
{'conn':  70, 'latency':  36.852 , 'tps':  1899.500160, 'init_conn_time':  37.879 },
{'conn':  80, 'latency':  46.817 , 'tps':  1708.784648, 'init_conn_time':  43.734 },
{'conn':  90, 'latency':  48.196 , 'tps':  1867.382635, 'init_conn_time':  44.725 },
{'conn':  100, 'latency':  54.900 , 'tps':  1821.503578, 'init_conn_time':  52.853 },
{'conn':  110, 'latency':  66.793 , 'tps':  1646.886561, 'init_conn_time':  57.561 },
{'conn':  120, 'latency':  68.077 , 'tps':  1762.699516, 'init_conn_time':  66.549 },
{'conn':  150, 'latency':  88.986 , 'tps':  1685.664101, 'init_conn_time':  98.959 },
{'conn':  200, 'latency':  130.729 , 'tps':  1529.877747, 'init_conn_time':  113.956 },
{'conn':  300, 'latency':  225.188 , 'tps':  1332.219598, 'init_conn_time':  160.221 },
{'conn':  400, 'latency':  362.184 , 'tps':  1104.411323, 'init_conn_time':  222.731 },
{'conn':  500, 'latency':  536.541 , 'tps':  931.895754, 'init_conn_time':  245.508 },
{'conn':  600, 'latency':  731.759 , 'tps':  819.942085, 'init_conn_time':  298.771 },
{'conn':  700, 'latency':  1200.487 , 'tps':  583.096548, 'init_conn_time':  341.147 },
{'conn':  800, 'latency':  1344.886 , 'tps':  594.845957, 'init_conn_time':  382.831 },
{'conn':  900, 'latency':  1783.656 , 'tps':  504.581742, 'init_conn_time':  458.334 },
{'conn':  1000, 'latency':  2456.054 , 'tps':  407.157138, 'init_conn_time':  489.128 },

    ]

import matplotlib.pyplot as plt

x = [x['conn'] for x in default]
y = [x['latency'] for x in default]

q = [x['conn'] for x in configured]
w = [x['latency'] for x in configured]

fig, ax = plt.subplots()

default_f, = ax.plot(x, y, label='default')
configured_f, = ax.plot(q, w, label='configured')
ax.legend(handles=[default_f, configured_f])
plt.title('Зависимость latency от числа подключений')
plt.ylabel('latency, ms')
plt.xlabel('connections count')
plt.show()

# %%
x = [x['conn'] for x in default[15:]]
y = [x['latency'] for x in default[15:]]

q = [x['conn'] for x in configured[15:]]
w = [x['latency'] for x in configured[15:]]

fig, ax = plt.subplots()

default_f, = ax.plot(x, y, label='default')
configured_f, = ax.plot(q, w, label='configured')
ax.legend(handles=[default_f, configured_f])
plt.title('Зависимость latency от числа подключений, 600-1000 connctions')
plt.ylabel('latency, ms')
plt.xlabel('connections count')
plt.show()

# %%
x = [x['conn'] for x in default[11:]]
y = [x['tps'] for x in default[11:]]

q = [x['conn'] for x in configured[11:]]
w = [x['tps'] for x in configured[11:]]

fig, ax = plt.subplots()

default_f, = ax.plot(x, y, label='default')
configured_f, = ax.plot(q, w, label='configured')
ax.legend(handles=[default_f, configured_f])
plt.title('Зависимость пропускной способности от числа подключений')
plt.ylabel('tps')
plt.xlabel('connections count')
plt.show()
